# %% [markdown]
# # AquaGuard AI/ML Notebook 02: Feature Analysis & Correlation
#
# This notebook analyzes spectral index trends (MNDWI, NDWI, NDVI), water area shrinkage, and correlation matrices for feature selection.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

ml_path = Path('../../data/datasets/ml_features.csv')
if ml_path.exists():
    df_ml = pd.read_csv(ml_path)
    print(f"ML features loaded: {df_ml.shape}")
    display(df_ml.describe())
else:
    print("ML features file not found. Run feature_engineering.py first.")
