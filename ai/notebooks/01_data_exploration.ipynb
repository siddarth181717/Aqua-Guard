# %% [markdown]
# # AquaGuard AI/ML Notebook 01: Data Exploration & Quality Audit
#
# This notebook inspects the multi-source dataset (`water_body_features.csv` and `ml_features.csv`) for missing values, distributions, temporal trends, and quality flags.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

data_path = Path('../../data/datasets/water_body_features.csv')
if data_path.exists():
    df = pd.read_csv(data_path)
    print(f"Dataset shape: {df.shape}")
    display(df.head())
else:
    print("Dataset file not found. Run geospatial dataset builder first.")
