# %% [markdown]
# # AquaGuard AI/ML Notebook 03: Candidate Model Training & Benchmarking
#
# This notebook benchmarks Logistic Regression, Decision Tree, Random Forest, and Gradient Boosting models using leakage-free temporal splits.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('../..').resolve()))

from ai.models.train import ModelTrainer

trainer = ModelTrainer()
best_model, metadata = trainer.train_and_select_best()
print(f"Best model trained: {metadata['model_name']}")
